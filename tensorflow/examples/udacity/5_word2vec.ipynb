# %% [markdown]
# Deep Learning
# =============
#
# Assignment 5
# ------------
#
# The goal of this assignment is to train a skip-gram model over [Text8](http://mattmahoney.net/dc/textdata) data.

# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
from __future__ import print_function
import collections
import math
import numpy as np
import os
import random
import tensorflow as tf
import zipfile
from matplotlib import pylab
from six.moves import range
from six.moves.urllib.request import urlretrieve
from sklearn.manifold import TSNE

# %% [markdown]
# Download the data from the source website if necessary.

# %%
url = 'http://mattmahoney.net/dc/'

def maybe_download(filename, expected_bytes):
  """Download a file if not present, and make sure it's the right size."""
  if not os.path.exists(filename):
    filename, _ = urlretrieve(url + filename, filename)
  statinfo = os.stat(filename)
  if statinfo.st_size == expected_bytes:
    print('Found and verified %s' % filename)
  else:
    print(statinfo.st_size)
    raise Exception(
      'Failed to verify ' + filename + '. Can you get to it with a browser?')
  return filename

filename = maybe_download('text8.zip', 31344016)
# Out:
# Found and verified text8.zip

# %% [markdown]
# Read the data into a string.

# %%
def read_data(filename):
  f = zipfile.ZipFile(filename)
  for name in f.namelist():
    return tf.compat.as_str(f.read(name)).split()
  f.close()
  
words = read_data(filename)
print('Data size %d' % len(words))
# Out:
# Data size 17005207

# %% [markdown]
# Build the dictionary and replace rare words with UNK token.

# %%
vocabulary_size = 50000

def build_dataset(words):
  count = [['UNK', -1]]
  count.extend(collections.Counter(words).most_common(vocabulary_size - 1))
  dictionary = dict()
  for word, _ in count:
    dictionary[word] = len(dictionary)
  data = list()
  unk_count = 0
  for word in words:
    if word in dictionary:
      index = dictionary[word]
    else:
      index = 0  # dictionary['UNK']
      unk_count = unk_count + 1
    data.append(index)
  count[0][1] = unk_count
  reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys())) 
  return data, count, dictionary, reverse_dictionary

data, count, dictionary, reverse_dictionary = build_dataset(words)
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10])
del words  # Hint to reduce memory.
# Out:
# Most common words (+UNK) [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]
# Sample data [5239, 3084, 12, 6, 195, 2, 3137, 46, 59, 156]

# %% [markdown]
# Function to generate a training batch for the skip-gram model.

# %%
data_index = 0

def generate_batch(batch_size, num_skips, skip_window):
  global data_index
  assert batch_size % num_skips == 0
  assert num_skips <= 2 * skip_window
  batch = np.ndarray(shape=(batch_size), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
  span = 2 * skip_window + 1 # [ skip_window target skip_window ]
  buffer = collections.deque(maxlen=span)
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  for i in range(batch_size // num_skips):
    target = skip_window  # target label at the center of the buffer
    targets_to_avoid = [ skip_window ]
    for j in range(num_skips):
      while target in targets_to_avoid:
        target = random.randint(0, span - 1)
      targets_to_avoid.append(target)
      batch[i * num_skips + j] = buffer[skip_window]
      labels[i * num_skips + j, 0] = buffer[target]
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:8]])

for num_skips, skip_window in [(2, 1), (4, 2)]:
    data_index = 0
    batch, labels = generate_batch(batch_size=8, num_skips=num_skips, skip_window=skip_window)
    print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
    print('    batch:', [reverse_dictionary[bi] for bi in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(8)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
#
# with num_skips = 2 and skip_window = 1:
#     batch: ['originated', 'originated', 'as', 'as', 'a', 'a', 'term', 'term']
#     labels: ['anarchism', 'as', 'a', 'originated', 'term', 'as', 'of', 'a']
#
# with num_skips = 4 and skip_window = 2:
#     batch: ['as', 'as', 'as', 'as', 'a', 'a', 'a', 'a']
#     labels: ['anarchism', 'term', 'a', 'originated', 'originated', 'as', 'of', 'term']

# %% [markdown]
# Train a skip-gram model.

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right.
num_skips = 2 # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default():

  # Input data.
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  # Variables.
  embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  softmax_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Model.
  # Look up embeddings for inputs.
  embed = tf.nn.embedding_lookup(embeddings, train_dataset)
  # Compute the softmax loss, using a sample of the negative labels each time.
  loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(softmax_weights, softmax_biases, embed,
                               train_labels, num_sampled, vocabulary_size))

  # Optimizer.
  optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
    normalized_embeddings, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
  tf.initialize_all_variables().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_data, batch_labels = generate_batch(
      batch_size, num_skips, skip_window)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in xrange(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in xrange(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 8.131591
# Nearest to however: partaking, tags, doctorate, munitions, dustin, naming, simplest, spoiling,
# Nearest to time: sail, consubstantiation, karelian, polskiej, convincing, sud, glean, hasidism,
# Nearest to there: idiom, chasm, ussr, habermas, patricians, rooke, menachem, cocaine,
# Nearest to in: cluetrain, wieman, ensue, forth, ksr, homeless, sar, celebrities,
# Nearest to been: finalist, responding, airlines, tumble, noriega, brin, housing, timothy,
# Nearest to of: americans, prefectures, patriotic, libel, obrzeg, cmm, stallion, qarase,
# Nearest to for: vocalized, quadrangle, shelf, developed, masamune, castrati, hiroshima, pharos,
# Nearest to four: mozambique, lea, satsuki, heian, earthquake, exercise, marcantonio, siona,
# Nearest to has: habit, accent, backgrounds, jing, polymaths, mand, reigning, resist,
# Nearest to as: ceded, desiderius, treachery, rajiv, casket, lengths, dissatisfaction, mcfarlane,
# Nearest to than: consequently, straddles, flooded, dien, tonal, nourishment, seismic, cladogram,
# Nearest to while: discharged, crannog, necessity, override, householder, eurosceptics, astra, nightmares,
# Nearest to new: telharmonium, ortega, cousins, boleyn, thujone, xj, disassembled, animistic,
# Nearest to they: breslau, honeymoon, misinterpretation, stepney, escorting, dugout, voyaging, swelling,
# Nearest to state: dorsey, welwyn, jhana, fie, volunteered, zambian, sufferer, minted,
# Nearest to or: nitrates, celled, mites, towed, fiendish, issuing, hemispheres, bresson,
# Average loss at step 2000: 4.353671
# Average loss at step 4000: 3.865661
# Average loss at step 6000: 3.786789
# Average loss at step 8000: 3.691260
# Average loss at step 10000: 3.619232
# Nearest to however: simplest, sn, included, stoics, vintage, tetris, paulinus, visibly,
# Nearest to time: sud, exhortations, practise, man, codify, task, polskiej, about,
# Nearest to there: it, he, not, they, now, often, maior, this,
# Nearest to in: at, of, on, from, with, elamite, lictors, wieman,
# Nearest to been: tumble, be, timothy, indented, finalist, karamazov, was, hastily,
# Nearest to of: in, during, kneel, throughout, same, stargate, cosmogony, attributable,
# Nearest to for: spans, quadrangle, ernst, with, lay, capacitors, futurism, logical,
# Nearest to four: three, eight, six, five, seven, two, nine, zero,
# Nearest to has: is, was, had, have, metrics, banjo, habit, bamar,
# Nearest to as: comparative, desiderius, mcfarlane, phenols, elmira, small, treehouse, xinhua,
# Nearest to than: or, straddles, dien, consequently, nourishment, flooded, hammering, whilst,
# Nearest to while: mixolydian, crannog, astra, hulled, israelites, genghis, pointed, communicating,
# Nearest to new: telharmonium, animistic, hawkins, basica, ortega, landes, boleyn, cousins,
# Nearest to they: he, it, not, there, references, misinterpretation, stepney, elizabethan,
# Nearest to state: jhana, welwyn, mythic, complicated, chickenpox, kyrgyzstan, hermon, decimal,
# Nearest to or: and, than, kri, composite, hangul, changing, acapulco, caring,
# Average loss at step 12000: 3.610753
# Average loss at step 14000: 3.569943
# Average loss at step 16000: 3.412114
# Average loss at step 18000: 3.457737
# Average loss at step 20000: 3.540923
# Nearest to however: but, simplest, included, that, uncharacteristic, exaltation, sn, delocalized,
# Nearest to time: sud, task, exhortations, idyllic, years, practise, sail, trials,
# Nearest to there: it, they, he, which, often, now, still, usually,
# Nearest to in: at, on, and, from, for, with, under, by,
# Nearest to been: be, become, tumble, were, karamazov, minos, also, was,
# Nearest to of: for, during, in, scathing, gearing, butterfly, fuchs, cognitive,
# Nearest to for: of, in, or, by, spans, respects, moravians, atheist,
# Nearest to four: three, six, five, seven, eight, two, nine, zero,
# Nearest to has: had, have, was, is, ostwald, having, mangeshkar, preservative,
# Nearest to as: desiderius, deified, voivodship, astrolabe, mcfarlane, grandsons, hideki, huge,
# Nearest to than: or, dien, straddles, nourishment, hammering, cladogram, sacked, aveiro,
# Nearest to while: during, communicating, like, astra, but, genghis, does, grips,
# Nearest to new: animistic, hawkins, ortega, telharmonium, basica, cousins, narcotic, mods,
# Nearest to they: he, we, there, it, you, not, she, who,
# Nearest to state: bipeds, jhana, unbreakable, kyrgyzstan, decimal, endpoint, complicated, ranching,
# Nearest to or: and, than, changing, for, meade, biz, alberti, imposes,
# Average loss at step 22000: 3.505852
# Average loss at step 24000: 3.487804
# Average loss at step 26000: 3.480708
# Average loss at step 28000: 3.478486
# Average loss at step 30000: 3.502813
# Nearest to however: but, uncharacteristic, argue, included, that, simplest, vintage, provoking,
# Nearest to time: sud, exhortations, intimately, practise, glean, saviour, lagoon, alkaloids,
# Nearest to there: they, it, he, now, often, still, we, this,
# Nearest to in: at, on, of, and, until, during, wieman, under,
# Nearest to been: become, be, were, shunning, was, minos, karamazov, tumble,
# Nearest to of: in, for, initial, and, from, programmatic, gearing, ultimate,
# Nearest to for: of, when, cylinders, attic, nijmegen, jigs, on, capacitors,
# Nearest to four: five, six, three, eight, seven, two, nine, zero,
# Nearest to has: had, have, is, was, having, mangeshkar, dendrites, agriculture,
# Nearest to as: elmira, futurism, deified, phenols, tate, desiderius, stylistically, fusion,
# Nearest to than: straddles, dien, or, much, demon, somewhat, cladogram, hammering,
# Nearest to while: but, when, like, though, communicating, devouring, does, daikaiju,
# Nearest to new: animistic, rust, hawkins, imperial, mods, arabic, auctioned, basica,
# Nearest to they: there, we, he, you, it, not, who, these,
# Nearest to state: bipeds, complicated, everson, hermon, unbreakable, chickenpox, states, kyrgyzstan,
# Nearest to or: and, rashid, than, boomerangs, whispering, blaise, intension, as,
# Average loss at step 32000: 3.505001
# Average loss at step 34000: 3.490710
# Average loss at step 36000: 3.450866
# Average loss at step 38000: 3.297529
# Average loss at step 40000: 3.426894
# Nearest to however: but, that, although, though, simplest, when, autonomous, endeavoured,
# Nearest to time: day, sud, lagoon, practise, exhortations, intimately, year, man,
# Nearest to there: they, it, he, now, still, which, usually, often,
# Nearest to in: during, of, from, for, on, and, at, to,
# Nearest to been: become, be, was, were, had, shunning, finalist, karamazov,
# Nearest to of: in, scathing, obedient, for, from, obligate, kneel, same,
# Nearest to for: in, nijmegen, of, tong, when, on, capacitors, strangeness,
# Nearest to four: three, six, five, seven, two, eight, nine, one,
# Nearest to has: had, have, was, is, argues, having, agriculture, replicas,
# Nearest to as: deified, treehouse, by, elmira, stylistically, whispering, daggers, divinity,
# Nearest to than: or, straddles, much, tropic, sacked, nourishment, somewhat, dien,
# Nearest to while: when, and, though, like, but, daikaiju, were, although,
# Nearest to new: animistic, rust, hawkins, imperial, upbeat, perpetuity, oblique, boleyn,
# Nearest to they: we, there, you, he, it, i, these, not,
# Nearest to state: government, bipeds, everson, unbreakable, kyrgyzstan, newsmagazine, chickenpox, muslims,
# Nearest to or: and, than, any, subscription, whispering, a, eugenie, lite,
# Average loss at step 42000: 3.433838
# Average loss at step 44000: 3.454017
# Average loss at step 46000: 3.448547
# Average loss at step 48000: 3.353723
# Average loss at step 50000: 3.381570
# Nearest to however: but, although, though, that, when, where, while, since,
# Nearest to time: day, year, sud, intimately, man, way, idyllic, task,
# Nearest to there: they, it, he, now, still, she, we, nosferatu,
# Nearest to in: during, of, from, until, within, since, on, including,
# Nearest to been: become, be, was, finalist, shunning, had, already, were,
# Nearest to of: in, from, fuchs, and, including, like, scathing, pavlov,
# Nearest to for: eapc, ideograms, concert, after, financial, stabilised, oa, specially,
# Nearest to four: seven, eight, six, five, three, nine, two, zero,
# Nearest to has: had, have, was, is, argues, having, hofstadter, powerplant,
# Nearest to as: deified, desiderius, gilmour, phenols, elmira, karaca, when, techstep,
# Nearest to than: or, much, but, straddles, somewhat, sacked, nourishment, hammering,
# Nearest to while: when, though, although, after, but, however, daikaiju, before,
# Nearest to new: introduces, rust, imperial, auctioned, hawkins, animistic, letterboxing, corte,
# Nearest to they: there, we, he, you, it, these, she, i,
# Nearest to state: everson, kyrgyzstan, bipeds, government, newsmagazine, lemmings, unbreakable, connotation,
# Nearest to or: and, than, candy, beet, while, homer, caring, weiser,
# Average loss at step 52000: 3.433994
# Average loss at step 54000: 3.429875
# Average loss at step 56000: 3.437873
# Average loss at step 58000: 3.396564
# Average loss at step 60000: 3.394523
# Nearest to however: but, although, though, that, which, since, when, nilo,
# Nearest to time: sud, day, period, intimately, lagoon, year, idyllic, starbucks,
# Nearest to there: they, it, now, this, she, we, he, still,
# Nearest to in: within, during, of, including, until, throughout, from, at,
# Nearest to been: become, be, was, were, had, finalist, shunning, already,
# Nearest to of: for, in, obedient, like, cognitive, biol, programmatic, same,
# Nearest to for: of, wilkins, fjords, thesis, ideograms, in, or, storage,
# Nearest to four: five, six, seven, eight, three, nine, two, zero,
# Nearest to has: had, have, is, was, having, argues, operates, mattathias,
# Nearest to as: deified, stylistically, by, centro, elmira, liar, fusion, astrolabe,
# Nearest to than: much, or, but, somewhat, straddles, demon, hammering, and,
# Nearest to while: although, when, though, before, after, daikaiju, during, like,
# Nearest to new: auctioned, nabla, cordon, battista, fushimi, animistic, goodies, hawkins,
# Nearest to they: we, there, you, he, she, these, i, not,
# Nearest to state: government, newsmagazine, everson, lemmings, bipeds, giambattista, kyrgyzstan, muslims,
# Nearest to or: and, than, caring, graz, but, vines, for, conscripted,
# Average loss at step 62000: 3.240442
# Average loss at step 64000: 3.252228
# Average loss at step 66000: 3.405324
# Average loss at step 68000: 3.398511
# Average loss at step 70000: 3.354815
# Nearest to however: but, although, though, that, where, which, while, since,
# Nearest to time: year, period, lagoon, sud, proportions, case, complicated, season,
# Nearest to there: they, it, we, now, he, she, usually, still,
# Nearest to in: within, during, on, until, hizballah, throughout, for, including,
# Nearest to been: become, be, were, already, was, minos, finalist, shunning,
# Nearest to of: including, like, for, obedient, although, biol, courier, programmatic,
# Nearest to for: including, after, in, of, ideograms, or, to, if,
# Nearest to four: six, five, seven, three, eight, two, nine, zero,
# Nearest to has: had, have, was, is, argues, contains, having, shaky,
# Nearest to as: deified, employee, desiderius, when, phenols, stylistically, woollen, elmira,
# Nearest to than: much, or, somewhat, demon, lifes, but, straddles, sacked,
# Nearest to while: although, though, before, when, like, but, where, including,
# Nearest to new: cordon, auctioned, goodies, specific, hawkins, nabla, mental, borrelly,
# Nearest to they: we, there, he, you, it, she, these, texan,
# Nearest to state: government, bipeds, newsmagazine, states, kyrgyzstan, unbreakable, lemmings, federal,
# Nearest to or: and, than, while, for, rashid, caring, the, pagan,
# Average loss at step 72000: 3.379984
# Average loss at step 74000: 3.349371
# Average loss at step 76000: 3.316872
# Average loss at step 78000: 3.355764
# Average loss at step 80000: 3.378175
# Nearest to however: although, but, though, that, while, where, since, they,
# Nearest to time: year, proportions, lagoon, sud, saviour, antipathy, days, ryukyu,
# Nearest to there: it, they, he, we, she, usually, now, still,
# Nearest to in: during, within, on, until, since, throughout, at, movable,
# Nearest to been: become, be, was, were, already, cruises, finalist, shunning,
# Nearest to of: including, forsyth, forgive, butterfly, ultimate, in, sous, hayao,
# Nearest to for: quadrangle, namely, fai, after, including, fjords, strangeness, lcm,
# Nearest to four: five, six, three, eight, seven, nine, two, zero,
# Nearest to has: had, have, is, was, since, argues, shaky, although,
# Nearest to as: desiderius, phenols, lorne, deified, overheard, before, fusion, techstep,
# Nearest to than: much, while, or, straddles, lifes, but, somewhat, like,
# Nearest to while: although, though, but, when, after, however, before, daikaiju,
# Nearest to new: hawkins, fushimi, battista, borrelly, rust, muon, auctioned, amiga,
# Nearest to they: we, he, there, you, she, it, these, who,
# Nearest to state: government, newsmagazine, lemmings, city, bipeds, berkeley, states, afghan,
# Nearest to or: and, than, while, caring, but, amphitheatre, homer, rainbows,
# Average loss at step 82000: 3.406312
# Average loss at step 84000: 3.410943
# Average loss at step 86000: 3.390066
# Average loss at step 88000: 3.355447
# Average loss at step 90000: 3.366466
# Nearest to however: but, although, that, though, while, additionally, since, they,
# Nearest to time: year, proportions, exhortations, season, saviour, day, lagoon, period,
# Nearest to there: they, it, we, he, she, now, still, usually,
# Nearest to in: during, within, with, under, orosius, until, between, on,
# Nearest to been: become, be, already, were, shunning, was, cruises, had,
# Nearest to of: for, including, current, include, ultimate, phobos, in, from,
# Nearest to for: of, when, including, during, after, by, if, gurdjieff,
# Nearest to four: seven, five, six, eight, three, two, nine, one,
# Nearest to has: had, have, is, was, argues, having, since, contains,
# Nearest to as: deified, stylistically, liar, elmira, gravestone, gilmour, centro, twisting,
# Nearest to than: much, or, somewhat, tropic, lifes, sectarianism, sacked, demon,
# Nearest to while: although, when, though, before, after, but, during, were,
# Nearest to new: auctioned, nssdc, hawkins, cordon, specific, goodies, battista, whewell,
# Nearest to they: we, he, there, she, you, it, constraints, soon,
# Nearest to state: government, city, newsmagazine, bipeds, lemmings, convenience, shiloh, berkeley,
# Nearest to or: and, graz, than, shemini, including, through, rashid, planetary,
# Average loss at step 92000: 3.401307
# Average loss at step 94000: 3.248513
# Average loss at step 96000: 3.351806
# Average loss at step 98000: 3.243797
# Average loss at step 100000: 3.358538
# Nearest to however: but, although, that, though, especially, where, and, while,
# Nearest to time: year, proportions, antipathy, season, lagoon, period, sud, day,
# Nearest to there: they, we, he, now, it, still, she, often,
# Nearest to in: during, within, among, throughout, until, from, on, at,
# Nearest to been: become, be, already, were, was, shunning, remained, finalist,
# Nearest to of: forgive, including, in, kneel, and, depicting, latest, programmatic,
# Nearest to for: when, including, after, while, during, lcm, before, despite,
# Nearest to four: seven, five, six, eight, nine, three, two, zero,
# Nearest to has: had, have, was, is, since, argues, contains, gives,
# Nearest to as: deified, like, gilmour, zealanders, whispering, astrolabe, elevators, pep,
# Nearest to than: or, much, while, tropic, sectarianism, hybrids, lifes, somewhat,
# Nearest to while: when, although, though, after, before, where, but, and,
# Nearest to new: specific, hawkins, auctioned, cordon, broncos, goodies, borrelly, muon,
# Nearest to they: we, he, there, you, she, it, i, these,
# Nearest to state: city, newsmagazine, lemmings, government, convenience, bipeds, shiloh, coalition,
# Nearest to or: and, than, rashid, while, monophosphate, dis, kata, uncut,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
# %matplotlib inline
def plot(embeddings, labels):
  assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
  pylab.figure(figsize=(15,15))  # in inches
  for i, label in enumerate(labels):
    x, y = embeddings[i,:]
    pylab.scatter(x, y)
    pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
  pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)

# %% [markdown]
# ---
#
# Problem
# -------
#
# An alternative to Word2Vec is called [CBOW](http://arxiv.org/abs/1301.3781) (Continuous Bag of Words). In the CBOW model, instead of predicting a context word from a word vector, you predict a word from the sum of all the word vectors in its context. Implement and evaluate a CBOW model trained on the text8 dataset.
#
# ---
